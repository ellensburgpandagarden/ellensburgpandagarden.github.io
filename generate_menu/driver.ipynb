# %%
from google.colab import drive 
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/pg_app/

# !pip install python-docx
# !python3 driver.py
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/pg_app
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.6 MB 5.2 MB/s
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=b540888758e424e7e99a0351943077cb195fda90823b731b80958d204eda986a
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
# Successfully built python-docx
# ...
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# ...
